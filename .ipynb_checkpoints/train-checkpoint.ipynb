# %%
import numpy as np
import os
import argparse
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import models
import pandas
import json
import unicodedata
import re

# %%
PATH = './release/train/ca_data/'
dum_path = './release/train/json_data/'
allFileList = os.listdir(PATH)
excel_list=[]
name_list=[]
for file in allFileList:
    #print((PATH+file))
    name_list.append(file)
    excel_list.append(pandas.read_excel(PATH+file))

# %%
## len(excel_list[0]) = 121 * 8
excel_list[0]
# Out:
#      Page No                                      Text  Index  Parent Index  \
# 0          1                                   入 札 公 告      1           NaN
# 1          1                         次のとおり一般競争入札に付します。      2           1.0
# 2          1                                平成３０年１月１８日      3           1.0
# 3          1                     独立行政法人石油天然ガス・金属鉱物資源機構      4           1.0
# 4          1                       契約担当役 資源備蓄本部長 渡辺 正俊      5           1.0
# ..       ...                                       ...    ...           ...
# 116        4  ① 契約締結日時点で在職している機構ＯＢに係る情報（人数、現在の職名及び機構にお    117         116.0
# 117        4                                  ける最終職名等）    118         116.0
# 118        4        ② 直近の事業年度における総売上高又は事業収入及び機構との間の取引高    119         116.0
# 119        4                                    （４）公表日    120          88.0
# 120        4                  契約締結日の翌日から起算して原則として９３日以内    121         120.0
#
#     Is Title  Is Table  Tag       Value
# 0          x       NaN  NaN         NaN
# 1        NaN       NaN  NaN         NaN
# 2        NaN       NaN  公告日  平成３０年１月１８日
# 3        NaN       NaN  NaN         NaN
# 4        NaN       NaN  NaN         NaN
# ..       ...       ...  ...         ...
# 116      NaN       NaN  NaN         NaN
# 117      NaN       NaN  NaN         NaN
# 118      NaN       NaN  NaN         NaN
# 119        x       NaN  NaN         NaN
# 120      NaN       NaN  NaN         NaN
#
# [121 rows x 8 columns]

# %%
for i in range(len(excel_list)):
    jsno_list={}
    for tags,value in zip(excel_list[i].Tag,excel_list[i].Value):
        if pandas.notnull(tags):
            print(tags)
            tags = unicodedata.normalize("NFKC", re.sub('＊|\*|\s+', '', tags))
            if tags in jsno_list:
                old_value = jsno_list[tags]
                jsno_list[tags] = str(old_value)+str(value)
            else:
                jsno_list[tags] = value
    jsObj = json.dumps(jsno_list)
    with open(dum_path+name_list[i]+'.json', "w") as f:  
        f.write(jsObj)  
        f.close()
# Out:
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# ＊入札書送付先
# ＊入札書送付先
# ＊入札書送付先　部署／担当者名
# ＊入札書送付先　部署／担当者名
# ＊入札書送付先　部署／担当者名
# ＊入札書送付先
# ＊入札書送付先　部署／担当者名
# ＊入札書送付先　部署／担当者名
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# 需要場所（住所）;都道府県
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 資格申請締切日時;入札書締切日時
# 公告日
# 入札件名
# 施設名;都道府県
# 調達開始日;調達終了日
# 需要場所（住所）;＊開札場所;＊入札書送付先
# 需要場所（住所）;都道府県;＊開札場所;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊開札場所
# 公告日
# 入札件名
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 需要場所（住所）
# 都道府県;需要場所（住所）
# 施設名
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# 需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# 需要場所（住所）;都道府県
# 施設名
# 資格申請締切日時
# ＊資格申請送付先
# ＊資格申請送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 入札書締切日時
# 開札日時
# ＊入札書送付先;＊開札場所
# ＊入札書送付先;＊開札場所
# ＊入札書送付先　部署／担当者名;＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊資格申請送付先;＊資格申請送付先　部署／担当者名
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 資格申請締切日時;入札書締切日時
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時;質問票締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊資格申請送付先;＊入札書送付先;＊開札場所
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 質問票締切日時
# 資格申請締切日時;入札書締切日時
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 需要場所（住所）
# 施設名
# 需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊質問箇所 所属／担当者
# 入札書締切日時
# 公告日
# 入札件名
# 入札件名
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# 需要場所（住所）;施設名;都道府県
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# ＊開札場所;開札日時
# 仕様書交付期限
# 公告日
# 入札件名
# 調達終了日
# 施設名
# 需要場所（住所）;都道府県
# 資格申請締切日時
# ＊入札書送付先
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 質問票締切日時
# 資格申請締切日時
# ＊資格申請送付先;＊資格申請送付先　部署／担当者名
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 調達終了日
# 需要場所（住所）;都道府県
# 施設名
# 施設名
# 資格申請締切日時
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 需要場所（住所）;都道府県
# 施設名
# 資格申請締切日時
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限;仕様書交付期限
# 入札書締切日時;開札日時
# 公告日
# 入札件名
# 需要場所（住所）
# 調達開始日
# 調達終了日
# 資格申請締切日時
# ＊資格申請送付先;＊入札書送付先;＊開札場所
# ＊資格申請送付先;＊入札書送付先;＊開札場所
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊入札書送付先;＊開札場所
# ＊入札書送付先　部署／担当者名;＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;施設名;需要場所（住所）
# 入札書締切日時
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊入札書送付先
# ＊入札書送付先　部署／担当者名
# ＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時;＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# 需要場所（住所）;都道府県
# 施設名
# ＊資格申請送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊入札書送付先;＊開札場所
# ＊入札書送付先　部署／担当者名;＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 質問票締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 資格申請締切日時
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 需要場所（住所）;都道府県
# 調達開始日;調達終了日
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 開札日時
# ＊開札場所
# ＊開札場所
# 資格申請締切日時;入札書締切日時
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊入札書送付先
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 施設名
# 需要場所（住所）;都道府県
# 調達開始日;調達終了日
# ＊資格申請送付先
# ＊資格申請送付先　部署／担当者名
# ＊入札書送付先
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 入札書締切日時;開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限;入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 調達開始日;調達終了日
# 資格申請締切日時
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 質問票締切日時
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# 資格申請締切日時
# ＊資格申請送付先
# ＊資格申請送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 入札書締切日時;開札日時
# ＊入札書送付先;＊開札場所
# ＊入札書送付先　部署／担当者名;＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 調達終了日
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名;＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 質問票締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊資格申請送付先
# ＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 質問票締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 資格申請締切日時
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊入札書送付先　部署／担当者名
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達年度
# 調達終了日
# 需要場所（住所）;都道府県
# 施設名
# 施設名
# 入札書締切日時;資格申請締切日時
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先　部署／担当者名;＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊資格申請送付先　部署／担当者名;＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊資格申請送付先　部署／担当者名;＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# 資格申請締切日時
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;施設名;需要場所（住所）
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時;＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# 資格申請締切日時
# ＊資格申請送付先;＊入札書送付先;＊開札場所
# ＊資格申請送付先;＊入札書送付先;＊開札場所
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 質問票締切日時
# 入札書締切日時;開札日時
# ＊入札書送付先;＊開札場所
# 公告日
# 入札件名
# 需要場所（住所）
# 施設名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# 需要場所（住所）;都道府県
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 資格申請締切日時;入札書締切日時
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 資格申請締切日時
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名;＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# ＊資格申請送付先
# ＊資格申請送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊入札書送付先;＊開札場所
# ＊入札書送付先　部署／担当者名;＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先
# ＊資格申請送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 資格申請締切日時
# 入札書締切日時;開札日時
# ＊入札書送付先;＊開札場所
# ＊入札書送付先　部署／担当者名;＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# ＊入札書送付先;＊入札書送付先　部署／担当者名
# 質問票締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日
# 調達終了日
# 都道府県;需要場所（住所）
# 施設名
# 施設名
# 資格申請締切日時
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日
# 資格申請締切日時
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 資格申請締切日時
# 仕様書交付期限
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日
# 調達終了日
# 都道府県;需要場所（住所）
# 施設名
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 開札日時
# ＊開札場所
# 資格申請締切日時
# 公告日
# 入札件名
# 都道府県;需要場所（住所）
# 施設名
# 資格申請締切日時
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達終了日;調達年度
# ＊資格申請送付先;＊入札書送付先
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ
# 質問票締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 需要場所（住所）;都道府県
# 調達開始日;調達終了日
# 資格申請締切日時
# ＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先;＊入札書送付先
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊資格申請送付先　部署／担当者名;＊入札書送付先　部署／担当者名
# ＊質問箇所　ＴＥＬ／ＦＡＸ
# 入札書締切日時
# 質問票締切日時
# 資格申請締切日時
# 開札日時
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達開始日;調達年度
# 調達終了日
# 施設名
# 需要場所（住所）;都道府県
# 入札書締切日時
# ＊入札書送付先
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊入札書送付先　部署／担当者名
# ＊入札書送付先
# ＊質問箇所 所属／担当者
# ＊質問箇所 所属／担当者;＊入札書送付先　部署／担当者名
# ＊質問箇所 所属／担当者;＊質問箇所　ＴＥＬ／ＦＡＸ;＊質問箇所　ＴＥＬ／ＦＡＸ;＊入札書送付先　部署／担当者名
# ＊資格申請送付先
# ＊資格申請送付先　部署／担当者名
# ＊資格申請送付先　部署／担当者名
# ＊資格申請送付先　部署／担当者名
# ＊資格申請送付先　部署／担当者名
# ＊資格申請送付先　部署／担当者名
# 開札日時
# ＊開札場所
# ＊開札場所
# ＊開札場所
# ＊開札場所
# 公告日
# 入札件名
# 調達年度;調達開始日;調達終了日
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# 施設名
# 都道府県;需要場所（住所）
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1dfe3befdb7c> in <module>
#       9                 #print((old_value))
#      10                 #print((value)s)
# ---> 11                 jsno_list[tags] = old_value+value
#      12             else:
#      13                 jsno_list[tags] = value
#
# TypeError: can only concatenate str (not "float") to str

# %%
# Out:
# 300351441.pdf.xlsx
